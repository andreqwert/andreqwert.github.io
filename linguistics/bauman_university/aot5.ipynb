# %% [markdown]
# # Домашнее задание №5
#
# Асланов А.Б., ИУ9-11М
#
# - Взять текст учебника и извлечь конструкции прилагательное-существительное
# - Упорядочить двумя способами
#   - по частотности
#   - по мере взаимной информации
#
# - Оценить, при каком методе терминов больше среди первых 20 словосочетаний
#
# В отчете д.б. не только показано, что именно извлечено, но и проведен анализ, почему словосочетание  - термин или не термин

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import re
import collections
import pandas as pd
from pymystem3 import Mystem
import json
from itertools import tee

# %%
with open('Введение_в_юриспруденцию.txt', 'r') as f:
    text = f.read()

# %%
# Обработка для получения лемм
lemm_text = ''.join(m.lemmatize(text))

# %%
# Удаляем знаки препинания
lemm_text = re.split("[\n;–,'''` .?!:'«»()]", lemm_text)

# Удаляем пустые строки
lemm_text = list(filter(None, lemm_text)) #None - потому что фильтрует пустые строки
words = [word.lower() for word in lemm_text] # все слова приводим к нижнему регистру

# %%
# Каждому слову присваиваем свою часть речи
m = Mystem()

init_text = ''
for word in words:
    init_text += str(word.lower())
    init_text += ' '

ws = m.analyze(init_text)
tags = []
for w in ws:
    try:
        word = w['text']
        tag = w['analysis'][0]['gr'].split(',')[0].split('=')[0]
        tags.append([word, tag])
    except:
        pass

tags = dict(tags)

# %%
# Строим словосочетания, где первым словом является прилагательное, а вторым - существительное
def pairwise(iterable):
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

adj_noun_bigrams = [k for k, v in zip(pairwise(tags.keys()), pairwise(tags.values())) if v[0] == 'A' and v[1] == 'S']
print(adj_noun_bigrams[:5000])
# Out:
# [('социальный', 'направленность'), ('юридический', 'профессия'), ('профессиональный', 'группа'), ('генеральный', 'сообщество'), ('правовой', 'регулирование'), ('основной', 'направление'), ('российский', 'федерация'), ('законотворческий', 'процесс'), ('политический', 'отношение'), ('противоречивый', 'характер'), ('правотворческий', 'задача'), ('господствующий', 'класс'), ('действующий', 'законодательство'), ('правильный', 'мотивация'), ('точный', 'сожаление'), ('неотложный', 'решение'), ('неопределенный', 'время'), ('федеральный', 'декабрь'), ('физический', 'лицо'), ('обозримый', 'перспектива'), ('активный', 'участие'), ('разнообразный', 'форма'), ('первоначальный', 'рабочий'), ('последний', 'момент'), ('нормативный', 'акт'), ('настоящий', 'роль'), ('заметный', 'увеличение'), ('полный', 'смысл'), ('подобный', 'оценка'), ('существенный', 'влияние'), ('необходимый', 'условие'), ('целый', 'ряд'), ('технический', 'прогресс'), ('негативный', 'урок'), ('соответствующий', 'вывод'), ('значительный', 'затрата'), ('первостепенный', 'значение'), ('финансовый', 'ресурс'), ('скорый', 'преодоление'), ('противный', 'случай'), ('демократический', 'диктатура'), ('простой', 'сотрясание'), ('правоприменительный', 'сфера'), ('большой', 'часть'), ('неуклонный', 'проведение'), ('занятый', 'масса'), ('переходный', 'период'), ('внутренний', 'дело'), ('тенденциозный', 'подход'), ('предварительный', 'следствие'), ('судебный', 'разбирательство'), ('нередкий', 'волокита'), ('человеческий', 'судьба'), ('преступный', 'поведение'), ('правоохранительный', 'оборотень'), ('криминальный', 'беспредел'), ('долгий', 'перестройка'), ('воспитательный', 'культура'), ('служебный', 'обязанность'), ('отрицательный', 'образ'), ('всемерный', 'активизация'), ('непосредственный', 'консультирование'), ('практический', 'взгляд'), ('эффективный', 'выполнение'), ('данный', 'характеристика'), ('должностной', 'работник'), ('смешанный', 'собственность'), ('определенный', 'служащий'), ('фактический', 'беззащитность'), ('разный', 'масть'), ('исполнительный', 'определение'), ('неверный', 'приказ'), ('организованный', 'структура'), ('административный', 'заключение'), ('подробный', 'анализ'), ('собственный', 'уровень'), ('многогранный', 'существо'), ('дополнительный', 'особенность'), ('технологический', 'план'), ('промышленный', 'производство'), ('отдельный', 'вид'), ('местный', 'самоуправление'), ('известный', 'набор'), ('взаимосвязанный', 'вертикаль'), ('следственный', 'управление'), ('подходящий', 'студент'), ('специальный', 'литература'), ('законный', 'основание'), ('уголовный', 'срок'), ('своевременный', 'расследование'), ('второстепенный', 'милиция'), ('воинский', 'соединение'), ('военный', 'изолятор'), ('пожарный', 'надзор'), ('оперативный', 'уполномоченная'), ('установленный', 'порядок'), ('справедливый', 'разрешение'), ('моральный', 'здоровье'), ('периодический', 'аттестация'), ('обширный', 'владение'), ('быстрый', 'раскрытие'), ('достоверный', 'сведение'), ('возможный', 'конфискация'), ('реальный', 'гарантия'), ('целое', 'взаимообусловленность'), ('бесспорный', 'утверждение'), ('достаточный', 'численность'), ('позитивный', 'готовность'), ('умный', 'мнение'), ('побочный', 'поступок'), ('продуктивный', 'мышление'), ('критический', 'обстановка'), ('посторонний', 'помощь'), ('блестящий', 'д'), ('выдающийся', 'поэт'), ('неизменный', 'политик'), ('совершенный', 'возбуждение'), ('личный', 'досмотр'), ('многоплановый', 'сторона'), ('принудительный', 'задержанный'), ('обвинительный', 'преследование'), ('умелый', 'организатор'), ('педагогический', 'поприще'), ('интересный', 'статья'), ('мудрый', 'наставник'), ('престижный', 'адвокатура'), ('адвокатский', 'стряпчество'), ('благоприятный', 'середина'), ('либеральный', 'устав'), ('популярный', 'термин'), ('постсоветский', 'пространство'), ('некоммерческий', 'оказание'), ('квалификационный', 'экзамен'), ('высококвалифицированный', 'профиль'), ('смежный', 'экономика'), ('письменный', 'консультация'), ('доверенный', 'имя'), ('краеугольный', ' ...

# %%
# Считаем биграммы по всему тексту
tokens = nltk.word_tokenize(init_text)
bigrams = list(nltk.bigrams(tokens))

countered_bigrams = dict(collections.Counter(bigrams))

countered_bigrams
# Out:
# {('сущность', 'и'): 3,
#  ('и', 'социальный'): 5,
#  ('социальный', 'направленность'): 1,
#  ('направленность', 'юридический'): 1,
#  ('юридический', 'профессия'): 14,
#  ('профессия', 'особенно'): 1,
#  ('особенно', 'отчетливо'): 1,
#  ('отчетливо', 'проявляться'): 1,
#  ('проявляться', 'в'): 1,
#  ('в', 'функция'): 1,
#  ('функция', 'юрист'): 2,
#  ('юрист', 'как'): 6,
#  ('как', 'социально-профессиональный'): 1,
#  ('социально-профессиональный', 'группа'): 1,
#  ('группа', 'генеральный'): 1,
#  ('генеральный', 'функция'): 1,
#  ('функция', 'юридический'): 4,
#  ('юридический', 'сообщество'): 2,
#  ('сообщество', 'профессиональный'): 1,
#  ('профессиональный', 'обеспечение'): 1,
#  ('обеспечение', 'механизм'): 1,
#  ('механизм', 'правовой'): 1,
#  ('правовой', 'регулирование'): 5,
#  ('регулирование', 'это'): 1,
#  ('это', 'предполагать'): 1,
#  ('предполагать', 'включение'): 1,
#  ('включение', 'весь'): 1,
#  ('весь', 'основной'): 2,
#  ('основной', 'направление'): 2,
#  ('направление', 'работа'): 1,
#  ('работа', 'юрист'): 5,
#  ('юрист', 'связывать'): 2,
#  ('связывать', 'с'): 16,
#  ('с', 'правотворчество'): 1,
#  ('правотворчество', 'применение'): 1,
#  ('применение', 'право'): 3,
#  ('право', 'профилактика'): 1,
#  ('профилактика', 'правонарушение'): 2,
#  ('правонарушение', 'правовой'): 1,
#  ('правовой', 'воспитание'): 5,
#  ('воспитание', 'нетрудно'): 1,
#  ('нетрудно', 'увидеть'): 1,
#  ('увидеть', 'что'): 1,
#  ('что', 'в'): 13,
#  ('в', 'свой'): 17,
#  ('свой', 'совокупность'): 1,
#  ('совокупность', 'они'): 1,
#  ('они', 'составлять'): 1,
#  ('составлять', 'основной'): 1,
#  ('основной', 'содержание'): 1,
#  ('содержание', 'мероприятие'): 1,
#  ('мероприятие', 'направлять'): 1,
#  ('направлять', 'на'): 5,
#  ('на', 'реализация'): 1,
#  ('реализация', 'правовой'): 2,
#  ('правовой', 'реформа'): 4,
#  ('реформа', 'отсюда'): 1,
#  ('отсюда', 'вытекать'): 1,
#  ('вытекать', 'важность'): 1,
#  ('важность', 'постоянный'): 1,
#  ('постоянный', 'ее'): 1,
#  ('ее', 'мониторинг'): 1,
#  ('мониторинг', 'выявление'): 1,
#  ('выявление', 'трудность'): 1,
#  ('трудность', 'и'): 1,
#  ('и', 'противоречие'): 1,
#  ('противоречие', 'о'): 1,
#  ('о', 'который'): 4,
#  ('который', 'речь'): 1,
#  ('речь', 'идти'): 2,
#  ('идти', 'в'): 1,
#  ('в', 'указ'): 1,
#  ('указ', 'президент'): 1,
#  ('президент', 'российский'): 1,
#  ('российский', 'федерация'): 72,
#  ('федерация', 'от'): 2,
#  ('от', '6'): 1,
#  ('6', 'июль'): 1,
#  ('июль', '1995'): 2,
#  ('1995', 'г'): 2,
#  ('г', 'о'): 2,
#  ('о', 'разработка'): 1,
#  ('разработка', 'концепция'): 1,
#  ('концепция', 'правовой'): 1,
#  ('реформа', 'в'): 2,
#  ('в', 'российский'): 12,
#  ('федерация', 'указ'): 1,
#  ('указ', 'быть'): 1,
#  ('быть', 'принимать'): 3,
#  ('принимать', 'в'): 6,
#  ('в', 'цель'): 3,
#  ('цель', 'реализация'): 1,
#  ('реализация', 'положение'): 1,
#  ('положение', 'конституция'): 3,
#  ('конституция', 'российский'): 8,
#  ('федерация', 'укрепление'): 1,
#  ('укрепление', 'на'): 1,
#  ('на', 'ее'): 1,
#  ('ее', 'основа'): 1,
#  ('основа', 'российский'): 2,
#  ('российский', 'государственность'): 1,
#  ('государственность', 'и'): 1,
#  ('и', 'правовой'): 6,
#  ('правовой', 'основа'): 1,
#  ('российский', 'общество'): 3,
#  ('общество', 'а'): 1,
#  ('а', 'также'): 18,
#  ('также', 'системность'): 1,
#  ('системность', 'плановость'): 1,
#  ('плановость', 'и'): 1,
#  ('и', 'скоординированность'): 1,
#  ('скоординированность', 'законотворческий'): 1,
#  ('законотворческий', 'процесс'): 1,
#  ('процесс', 'и'): 2,
#  ('и', 'хотя'): 1,
#  ('хотя', 'проходить'): 1,
#  ('проходить', 'уже'): 1,
#  ('уже', '10'): 1,
#  ('10', 'год'): 7,
#  ('год', 'со'): 1,
#  ('со', 'день'): 1,
#  ('день', 'он'): 1,
#  ('он', 'принятие'): 1,
#  ('принятие', 'отмечать'): 1,
#  ('отмечать', 'что'): 8,
#  ('что', 'развитие'): 1,
#  ('развитие', 'и'): 2,
#  ('правовой', 'оформление'): 1,
#  ('оформление', 'новый'): 1,
#  ('новый', 'экономический'): 1,
#  ('экономический', 'социальный'): 1,
#  ('социальный', 'и'): 1,
#  ('и', 'политический'): 1,
#  ('политический', 'отношение'): 1,
#  ('отношение', 'в'): 3,
#  ('в', 'россия'): 26,
#  ('россия', 'весь'): 1,
#  ('весь', 'еще'): 1,
#  ('еще', 'носить'): 1,
#  ('носить', 'недостаточно'): 1,
#  ('недостаточно', 'упорядочивать'): 1,
#  ('упорядочивать', 'неравномерный'): 1,
#  ('неравномерный', 'и'): 1,
#  ('и', 'противоречивый'): 1,
#  ('противоречивый', 'характер'): 1,
#  ('характер', 'в'): 2,
#  ('в', 'ход'): 8,
#  ('ход', 'реализация'): 1,
#  ('реализация', 'правотворческий'): 1,
#  ('правотворческий', 'функция'): 1,
#  ('функция', 'задача'): 1,
#  ('задача', 'юрист'): 1,
#  ('юрист', 'заключаться'): 1,
#  ('заключаться', 'прежде'): 1,
#  ('прежде', 'все'): 23,
#  ('все', 'в'): 3,
#  ('в', 'то'): 15,
#  ('то', 'чтобы'): 18,
#  ('чтобы', 'переводить'): 1,
#  ('переводить', 'на'): 2,
#  ('на', 'язык'): 1,
#  ('язык', 'правовой'): 1,
#  ('правовой', 'категория'): 1,
#  ('категория', 'и'): 1,
#  ('и', 'норма'): 1,
#  ('норма', 'потребность'): 1,
#  ('потребность', 'весь'): 1,
#  ('весь', 'общество'): 1,
#  ('общество', 'или'): 1,
#  ('или', 'экономически'): 1,
#  ('экономически', 'господствующий'): 1,
#  ('господствующий', 'класс'): 1,
#  ('класс', 'способствовать'): 1,
#  ('способствовать', 'трансформация'): 1,
#  ('трансформация', 'этот'): 1,
#  ('этот', 'воля'): 1,
#  ('воля', 'в'): 1,
#  ('в', 'государственный'): 5,
#  ('государственный', 'путем'): 1,
#  ('путем', 'закрепление'): 1,
#  ('закрепление', 'в'): 1,
#  ('в', 'закон'): 5,
#  ('закон', 'не'): 1,
#  ('не', 'менее'): 13,
#  ('менее', 'важный'): 1,
#  ('важный', 'для'): 1,
#  ('для', 'юрист'): 3,
#  ('юрист', 'обеспечивать'): 1,
#  ('обеспечивать', 'и'): 1,
#  ('и', 'непротиворечивость'): 2,
#  ('непротиворечивость', 'система'): 1,
#  ('система', 'действующий'): 1,
#  ('действующий', 'право'): 1,
#  ('право', 'законодательство'): 1,
#  ('законодательство', 'возможность'): 1,
#  ('возможность', 'достижение'): 1,
#  ('достижение', 'этот'): 1,
#  ('этот', 'объясняться'): 1,
#  ('объясняться', 'то'): 1,
#  ('то', 'что'): 26,
#  ('что', 'у'): 1,
#  ('у', 'юрист'): 1,
#  ('как', 'у'): 1,
#  ('у', 'профессионал'): 1,
#  ('профессионал', 'значительно'): 1,
#  ('значительно', 'высокий'): 1,
#  ('высокий', 'чем'): 1,
#  ('чем', 'у'): 1,
#  ('у', 'представитель'): 1,
#  ('представитель', 'другой'): 3,
#  ('другой', 'социальный'): 1,
#  ('социальный', 'группа'): 2,
#  ('группа', 'способность'): 1,
#  ('способность', 'к'): 2,
#  ('к', 'прием'): 1,
#  ('прием', 'переработка'): 1,
#  ('переработка', 'хранение'): 1,
#  ('хранение', 'и'): 1,
#  ('и', 'использование'): 2,
#  ('использование', 'правовой'): 3,
#  ('правовой', 'информация'): 1,
#  ('информация', 'это'): 1,
#  ('это', 'необходимо'): 2,
#  ('необходимо', 'учитывать'): 2,
#  ('учитывать', 'и'): 2,
#  ('и', 'при'): 2,
#  ('при', 'организация'): 1,
#  ('организация', 'современный'): 1,
#  ('современный', 'законодательный'): 1,
#  ('законодательный', 'процесс'): 2,
#  ('процесс', 'прежде'): 1,
#  ('все', 'следовать'): 2,
#  ('следовать', 'обеспечивать'): 1,
#  ('обеспечивать', 'правильный'): 1,
#  ('правильный', 'юридический'): 1,
#  ('юридический', 'мотивация'): 1,
#  ('мотивация', 'и'): 1,
#  ('и', 'точный'): 2,
#  ('точный', 'закрепление'): 1,
#  ('закрепление', 'потребность'): 1,
#  ('потребность', 'экономический'): 1,
#  ('экономический', 'развитие'): 1,
#  ('развитие', 'общество'): 2,
#  ('общество', 'к'): 2,
#  ('к', 'сожаление'): 3,
#  ('сожаление', 'этот'): 1,
#  ('этот', 'процесс'): 3,
#  ('процесс', 'сегодня'): 1,
#  ('сегодня', 'продолжать'): 1,
#  ('продолжать', 'сохранять'): 1,
#  ('сохранять', 'во'): 1,
#  ('во', 'многое'): 5,
#  ('многое', 'стихийный'): 1,
#  ('стихийный', 'характер'): 1,
#  ('характер', 'когда'): 1,
#  ('когда', 'требовать'): 1,
#  ('требовать', 'неотложный'): 1,
#  ('неотложный', 'принятие'): 1,
#  ('принятие', 'законодательный'): 1,
#  ('законодательный', 'решение'): 1,
#  ('решение', 'откладываться'): 1,
#  ('откладываться', 'на'): 1,
#  ('на', 'неопределенный'): 1,
#  ('неопределенный', 'время'): 1,
#  ('время', 'исчислять'): 1,
#  ('исчислять', 'год'): 1,
#  ('год', 'достаточно'): 1,
#  ('достаточно', 'ссылаться'): 1,
#  ('ссылаться', 'на'): 1,
#  ('на', 'история'): 1,
#  ('история', 'принятие'): 1,
#  ('принятие', 'федеральный'): 1,
#  ('федеральный', 'закон'): 10,
#  ('закон', 'от'): 2,
#  ('от', '23'): 1,
#  ('23', 'декабрь'): 1,
#  ('декабрь', '2003'): 1,
#  ('2003', 'г'): 1,
#  ('о', 'страхование'): 1,
#  ('страхование', 'вклад'): 1,
#  ('вклад', 'физический'): 1,
#  ('физический', 'лицо'): 3,
#  ('лицо', 'в'): 6,
#  ('в', 'банк'): 2,
#  ('банк', 'российский'): 1,
#  ('федерация', 'который'): 3,
#  ('который', 'растягиваться'): 1,
#  ('растягиваться', 'более'): 1,
#  ('более', 'чем'): 3,
#  ('чем', 'на'): 1,
#  ('на', '10'): 1,
#  ('год', 'следовательно'): 1,
#  ('следовательно', 'для'): 1,
#  ('юрист', 'участвовать'): 1,
#  ('участвовать', 'в'): 7,
#  ('в', 'правотворчество'): 2,
#  ('правотворчество', 'особенно'): 1,
#  ('особенно', 'в'): 3,
#  ('в', 'качество'): 17,
#  ('качество', 'депутат'): 1,
#  ('депутат', 'необходимо'): 1,
#  ('необходимо', 'как'): 1,
#  ('как', 'можно'): 1,
#  ('можно', 'глубоко'): 1,
#  ('глубоко', 'проникать'): 1,
#  ('проникать', 'в'): 1,
#  ('в', 'суть'): 1,
#  ('суть', 'правовой'): 1,
#  ('правовой', 'явление'): 1,
#  ('явление', 'в'): 2,
#  ('в', 'жизнь'): 5,
#  ('жизнь', 'общество'): 3,
#  ('общество', 'выявлять'): 1,
#  ('выявлять', 'и'): 1,
#  ('и', 'формулировать'): 1,
#  ('формулировать', 'закономерность'): 1,
#  ('закономерность', 'а'): 1,
#  ('также', 'точно'): 1,
#  ('точно', 'определять'): 1,
#  ('определять', 'тенденция'): 1,
#  ('тенденция', 'их'): 1,
#  ('их', 'дальнейший'): 1,
#  ('дальнейший', 'развитие'): 2,
#  ('развитие', 'на'): 1,
#  ('на', 'обозримый'): 1,
#  ('обозримый', 'перспектива'): 1,
#  ('перспектива', 'не'): 1,
#  ('менее', 'важно'): 1,
#  ('важно', 'обеспечивать'): 2,
#  ('обеспечивать', 'повседневный'): 1,
#  ('повседневный', 'и'): 1,
#  ('и', 'активный'): 2,
#  ('активный', 'участие'): 3,
#  ('участие', 'юрист'): 2,
#  ('юрист', 'в'): 39,
#  ('в', 'самый'): 4,
#  ('самый', 'разнообразный'): 1,
#  ('разнообразный', 'форма'): 1,
#  ('форма', 'и'): 2,
#  ('и', 'на'): 4,
#  ('на', 'весь'): 3,
#  ('весь', 'стадия'): 1,
#  ('стадия', 'правотворческий'): 1,
#  ('правотворческий', 'процесс'): 1,
#  ('процесс', 'включая'): 1,
#  ('включая', 'законодательный'): 1,
#  ('законодательный', 'необходимо'): 1,
#  ('необходимо', 'покончить'): 1,
#  ('покончить', 'с'): 1,
#  ('с', 'практика'): 1,
#  ('практика', 'когда'): 1,
#  ('когда', 'юрист'): 4,
#  ('в', 'тот'): 13,
#  ('тот', 'число'): 5,
#  ('число', 'крупный'): 1,
#  ('крупный', 'ученый'): 1,
#  ('ученый', 'привлекаться'): 1,
#  ('привлекаться', 'лишь'): 1,
#  ('лишь', 'для'): 1,
#  ('для', 'подготовка'): 2,
#  ('подготовка', 'болванка'): 1,
#  ('болванка', 'первоначальный'): 1,
#  ('первоначальный', 'рабочий'): 1,
#  ('рабочий', 'вариант'): 1,
#  ('вариант', 'законопроект'): 1,
#  ('законопроект', 'в'): 2,
#  ('в', 'который'): 8,
#  ('который', 'затем'): 1,
#  ('затем', 'нередко'): 1,
#  ('нередко', 'в'): 2,
#  ('самый', 'последний'): 1,
#  ('последний', 'момент'): 1,
#  ('момент', 'вноситься'): 1,
#  ('вноситься', 'без'): 1,
#  ('без', 'их'): 1,
#  ('их', 'ведомо'): 1,
#  ('ведомо', 'корректива'): 1,
#  ('корректива', 'противоречить'): 1,
#  ('противоречить', 'основной'): 1,
#  ('основной', 'идея'): 1,
#  ('идея', 'концепция'): 1,
#  ('концепция', 'нормативный'): 1,
#  ('нормативный', 'акт'): 4,
#  ('акт', 'это'): 1,
#  ('это', 'не'): 2,
#  ('не', 'только'): 15,
#  ('только', 'снижать'): 1,
#  ('снижать', 'эффективность'): 1,
#  ('эффективность', 'законотворчество'): 1,
#  ('законотворчество', 'но'): 1,
#  ('но', 'и'): 15,
#  ('и', 'серьезно'): 1,
#  ('серьезно', 'подрывать'): 1,
#  ('подрывать', 'престиж'): 1,
#  ('престиж', 'юридический'): 1,
#  ('юридический', 'наука'): 1,
#  ('наука', 'заинтересованность'): 1,
#  ('заинтересованность', 'юрист'): 1,
#  ('в', 'правотворческий'): 2,
#  ('правотворческий', 'деятельность'): 2,
#  ('деятельность', 'в'): 11,
#  ('в', 'настоящий'): 11,
#  ('настоящий', 'время'): 11,
#  ('время', 'роль'): 1,
#  ('роль', 'юрист'): 3,
#  ('в', 'законодательный'): 3,
#  ('процесс', 'должный'): 1,
#  ('должный', 'быть'): 26,
#  ('быть', 'серьезно'): 1,
#  ('серьезно', 'повышать'): 1,
#  ('повышать', 'во'): 1,
#  ('многое', 'этот'): 1,
#  ('этот', 'цель'): 1,
#  ('цель', 'мочь'): 1,
#  ('мочь', 'быть'): 43,
#  ('быть', 'достигать'): 1,
#  ('достигать', 'путем'): 1,
#  ('путем', 'заметный'): 1,
#  ('заметный', 'увеличение'): 1,
#  ('увеличение', 'представительство'): 1,
#  ('представительство', 'юрист'): 1,
#  ('как', 'в'): 4,
#  ('в', 'федеральный'): 1,
#  ('федеральный', 'собрание'): 1,
#  ('собрание', 'так'): 1,
#  ('так', 'и'): 11,
#  ('и', 'в'): 28,
#  ('законодательный', 'орган'): 1,
#  ('орган', 'субъект'): 1,
#  ('субъект', 'российский'): 18,
#  ('федерация', 'думаться'): 1,
#  ('думаться', 'что'): 1,
#  ('что', 'решение'): 1,
#  ('решение', 'рассматривать'): 1,
#  ('рассматривать', 'проблема'): 1,
#  ('проблема', 'мочь'): 1,
#  ('мочь', 'бы'): 2,
#  ('бы', 'также'): 1,
#  ('также', 'способствовать'): 1,
#  ('способствовать', 'установление'): 1,
#  ('установление', 'авторство'): 1,
#  ('авторство', 'тот'): 1,
#  ('тот', 'или'): 7,
#  ('или', 'иной'): 10,
#  ('иной', 'законопроект'): 1,
#  ('законопроект', 'юрист'): 1,
#  ('в', 'полный'): 3,
#  ('полный', 'смысл'): 1,
#  ('смысл', 'должный'): 1,
#  ('быть', 'творец'): 1,
#  ('творец', 'автор'): 1,
#  ('автор', 'законопроект'): 1,
#  ('законопроект', 'подобный'): 1,
#  ('подобный', 'практика'): 1,
#  ('практика', 'быть'): 2,
#  ('быть', 'способствовать'): 1,
#  ('способствовать', 'не'): 1,
#  ('только', 'правильный'): 1,
#  ('правильный', 'оценка'): 1,
#  ('оценка', 'вклад'): 1,
#  ('вклад', 'юрист'): 1,
#  ('деятельность', 'но'): 1,
#  ('и', 'повышение'): 1,
#  ('повышение', 'их'): 3,
#  ('их', 'ответственность'): 1,
#  ('ответственность', 'за'): 10,
#  ('за', 'состояние'): 1,
#  ('состояние', 'действовать'): 1,
#  ('действовать', 'законодательство'): 1,
#  ('законодательство', 'существенный'): 1,
#  ('существенный', 'влияние'): 1,
#  ('влияние', 'на'): 4,
#  ('на', 'построение'): 1,
#  ('построение', 'правовой'): 1,
#  ('правовой', 'государство'): 6,
#  ('государство', 'оказывать'): 1,
#  ('оказывать', 'также'): 1,
#  ('также', 'решение'): 1,
#  ('решение', 'о'): 1,
#  ('о', 'непротиворечивость'): 1,
#  ('непротиворечивость', 'и'): 1,
#  ('и', 'согласованность'): 1,
#  ('согласованность', 'действующий'): 1,
#  ('действующий', 'система'): 1,
#  ('система', 'право'): 2,
#  ('право', 'согласованность'): 1,
#  ('согласованность', 'и'): 1,
#  ('непротиворечивость', 'законодательство'): 1,
#  ('законодательство', 'необходимый'): 1,
#  ('необходимый', 'условие'): 3,
#  ('условие', 'его'): 1,
#  ('его', 'эффективность'): 1,
#  ('эффективность', 'обеспечение'): 1,
#  ('обеспечение', 'режим'): 1,
#  ('режим', 'законность'): 1,
#  ('законность', 'следовать'): 1,
#  ('следовать', 'признавать'): 1,
#  ('признавать', 'что'): 2,
#  ('что', 'современный'): 1,
#  ('современный', 'российский'): 1,
#  ('российский', 'законодательство'): 2,
#  ('законодательство', 'далеко'): 1,
#  ('далеко', 'не'): 6,
#  ('не', 'в'): 5,
#  ('полный', 'мера'): 1,
#  ('мера', 'соответствовать'): 1,
#  ('соответствовать', 'этот'): 1,
#  ('этот', 'требование'): 4,
#  ('требование', 'прежде'): 1,
#  ('все', 'это'): 4,
#  ('это', 'выражаться'): 1,
#  ('выражаться', 'в'): 3,
#  ('что', 'до'): 1,
#  ('до', 'настоящий'): 1,
#  ('время', 'целый'): 1,
#  ('целый', 'ряд'): 2,
#  ('ряд', 'положение'): 3,
#  ('федерация', 'не'): 1,
#  ('не', 'находить'): 1,
#  ('находить', 'свой'): 1,
#  ('свой', 'адекватный'): 1,
#  ('адекватный', 'развитие'): 1,
#  ('развитие', 'в'): 1,
#  ('в', 'конституционный'): 1,
#  ('конституционный', 'и'): 5,
#  ('и', 'текущий'): 1,
#  ('текущий', 'федеральный'): 1,
#  ('закон', 'то'): 2,
#  ('то', 'более'): 2,
#  ('более', 'нет'): 1,
#  ('нет', 'необходимость'): 1,
#  ('необходимость', 'говорить'): 1,
#  ('говорить', 'о'): 3,
#  ('о', 'несоответствие'): 1,
#  ('несоответствие', 'положение'): 1,
#  ('конституция', 'закон'): 1,
#  ('закон', 'принимать'): 1,
#  ('принимать', 'субъект'): 1,
#  ('федерация', 'хотя'): 1,
#  ('хотя', 'острота'): 1,
#  ('острота', 'этот'): 1,
#  ('этот', 'противоречие'): 1,
#  ('противоречие', 'в'): 2,
#  ('в', 'последний'): 6,
#  ('последний', 'год'): 5,
#  ('год', 'несколько'): 1,
#  ('несколько', 'снижаться'): 1,
#  ('снижаться', 'должный'): 1,
#  ('быть', 'закладывать'): 1,
#  ('закладывать', 'наконец'): 1,
#  ('наконец', 'новый'): 1,
#  ('новый', 'законодательный'): 1,
#  ('законодательный', 'практика'): 1,
#  ('практика', 'который'): 4,
#  ('который', 'являться'): 4,
#  ('являться', 'бы'): 1,
#  ('бы', 'основа'): 1,
#  ('основа', 'для'): 1,
#  ('для', 'создание'): 1,
#  ('создание', 'согласованный'): 1,
#  ('согласованный', 'и'): 1,
#  ('и', 'непротиворечивый'): 1,
#  ('непротиворечивый', 'законодательство'): 1,
#  ('законодательство', 'для'): 1,
#  ('для', 'это'): 2,
#  ('необходимо', 'использовать'): 1,
#  ('использовать', 'весь'): 1,
#  ('весь', 'опыт'): 1,
#  ('опыт', 'систематизация'): 1,
#  ('систематизация', 'законодательство'): 1,
#  ('законодательство', 'требование'): 1,
#  ('требование', 'законодательный'): 1,
#  ('законодательный', 'техника'): 2,
#  ('техника', 'достижение'): 1,
#  ('достижение', 'научно-'): 1,
#  ('научно-', 'технический'): 1,
#  ('технический', 'прогресс'): 1,
#  ('прогресс', 'важно'): 1,
#  ('важно', 'учитывать'): 1,
#  ('учитывать', 'негативный'): 1,
#  ('негативный', 'урок'): 1,
#  ('урок', 'прошлое'): 1,
#  ('прошлое', 'сделать'): 1,
#  ('сделать', 'соответствующий'): 1,
#  ('соответствующий', 'вывод'): 1,
#  ('вывод', 'как'): 1,
#  ('как', 'известно'): 5,
#  ('известно', 'в'): 1,
#  ('в', 'советский'): 7,
#  ('советский', 'так'): 1,
#  ('так', 'называть'): 6,
#  ('называть', 'застойный'): 1,
#  ('застойный', 'год'): 1,
#  ('год', 'законодательство'): 1,
#  ('законодательство', 'не'): 1,
#  ('только', 'противоречить'): 1,
#  ('противоречить', 'потребность'): 1,
#  ('потребность', 'общественный'): 1,
#  ('общественный', 'развитие'): 1,
#  ('развитие', 'но'): 1,
#  ('и', 'не'): 12,
#  ('не', 'быть'): 7,
#  ('быть', 'достаточно'): 3,
#  ('достаточно', 'внутренне'): 1,
#  ('внутренне', 'согласованный'): 1,
#  ('согласованный', 'этот'): 1,
#  ('этот', 'проблема'): 1,
#  ('проблема', 'не'): 1,
#  ('не', 'смочь'): 1,
#  ('смочь', 'решать'): 1,
#  ('решать', 'и'): 3,
#  ('и', 'потребовать'): 1,
#  ('потребовать', 'значительный'): 1,
#  ('значительный', 'затрата'): 1,
#  ('затрата', 'сила'): 1,
#  ('сила', 'и'): 3,
#  ('и', 'средство'): 1,
#  ('средство', 'подготовка'): 1,
#  ('подготовка', 'собрание'): 1,
#  ('собрание', 'действующий'): 1,
#  ('действующий', 'законодательство'): 9,
#  ('законодательство', 'ссср'): 1,
#  ('ссср', 'а'): 1,
#  ('а', 'затем'): 2,
#  ('затем', 'и'): 1,
#  ('и', 'свод'): 1,
#  ('свод', 'закон'): 3,
#  ('закон', 'ссср'): 1,
#  ('ссср', 'разбалансировка'): 1,
#  ('разбалансировка', 'действовать'): 1,
#  ('действовать', 'тогда'): 2,
#  ('тогда', 'законодательство'): 2,
#  ('законодательство', 'способствовать'): 1,
#  ('способствовать', 'также'): 1,
#  ('также', 'активный'): 1,
#  ('активный', 'правительственный'): 1,
#  ('правительственный', 'и'): 1,
#  ('и', 'ведомственный'): 1,
#  ('ведомственный', 'нормотворческий'): 1,
#  ('нормотворческий', 'деятельность'): 1,
#  ('деятельность', 'сегодня'): 1,
#  ('сегодня', 'появляться'): 1,
#  ('появляться', 'новый'): 1,
#  ('новый', 'болезнь'): 1,
#  ('болезнь', 'законодательный'): 1,
#  ('законодательный', 'власть'): 1,
#  ('власть', 'отсутствие'): 1,
#  ('отсутствие', 'единство'): 1,
#  ('единство', 'воля'): 1,
#  ('воля', 'лоббирование'): 1,
#  ('лоббирование', 'законопроект'): 1,
#  ('законопроект', 'не'): 1,
#  ('не', 'иметь'): 8,
#  ('иметь', 'первостепенный'): 1,
#  ('первостепенный', 'значение'): 1,
#  ('значение', 'необеспеченность'): 1,
#  ('необеспеченность', 'вновь'): 1,
#  ('вновь', 'принимать'): 1,
#  ('принимать', 'акт'): 1,
#  ('акт', 'необходимый'): 1,
#  ('необходимый', 'финансовый'): 1,
#  ('финансовый', 'ресурс'): 1,
#  ('ресурс', 'пренебрежение'): 1,
#  ('пренебрежение', 'законодательный'): 1,
#  ('техника', 'весь'): 1,
#  ('весь', 'этот'): 1,
#  ('этот', 'недостаток'): 2,
#  ('недостаток', 'нуждаться'): 1,
#  ('нуждаться', 'в'): 4,
#  ('в', 'скорый'): 1,
#  ('скорый', 'преодоление'): 1,
#  ('преодоление', 'в'): 1,
#  ('в', 'противный'): 2,
#  ('противный', 'случай'): 2,
#  ('случай', 'весь'): 1,
#  ('весь', 'разговор'): 1,
#  ('разговор', 'о'): 1,
#  ('о', 'предстоящий'): 1,
#  ('предстоящий', 'огромный'): 1,
#  ('огромный', 'по'): 1,
#  ('по', 'свой'): 3,
#  ('свой', 'объем'): 1,
#  ('объем', 'и'): 1,
#  ('и', 'масштаб'): 1,
#  ('масштаб', 'работа'): 1,
#  ('работа', 'по'): 20,
#  ('по', 'приведение'): 1,
#  ('приведение', 'действующий'): 1,
#  ('законодательство', 'в'): 3,
#  ('в', 'соответствие'): 18,
#  ('соответствие', 'с'): 19,
#  ('с', 'принцип'): 1,
#  ('принцип', 'демократический'): 1,
#  ('демократический', 'правовой'): 1,
#  ('государство', 'о'): 3,
#  ('о', 'диктатура'): 1,
#  ('диктатура', 'закон'): 1,
#  ('закон', 'так'): 1,
#  ('и', 'оставаться'): 2,
#  ('оставаться', 'простой'): 1,
#  ('простой', 'сотрясание'): 1,
#  ('сотрясание', 'воздух'): 1,
#  ('воздух', 'важный'): 1,
#  ('важный', 'функция'): 3,
#  ('профессия', 'правоприменительный'): 1,
#  ('правоприменительный', 'деятельность'): 3,
#  ('в', 'этот'): 16,
#  ('этот', 'сфера'): 2,
#  ('сфера', 'задействовать'): 1,
#  ('задействовать', 'большой'): 1,
#  ('большой', 'часть'): 1,
#  ('часть', 'профессиональный'): 1,
#  ('профессиональный', 'юрист'): 2,
#  ('юрист', 'заниматься'): 2,
#  ('заниматься', 'организация'): 1,
#  ('организация', 'претворение'): 1,
#  ('претворение', 'в'): 1,
#  ('жизнь', 'положение'): 1,
#  ('положение', 'законодательство'): 1,
#  ('законодательство', 'применение'): 1,
#  ('право', 'важный'): 1,
#  ('важный', 'звено'): 1,
#  ('звено', 'в'): 1,
#  ('в', 'система'): 3,
#  ('система', 'правовой'): 2,
#  ('регулирование', 'отсюда'): 1,
#  ('отсюда', 'то'): 1,
#  ('то', 'важный'): 1,
#  ('важный', 'значение'): 1,
#  ('значение', 'который'): 1,
#  ('который', 'иметь'): 6,
#  ('иметь', 'человек'): 1,
#  ('человек', 'осуществлять'): 1,
#  ('осуществлять', 'правоприменительный'): 1,
#  ('деятельность', 'обеспечивать'): 1,
#  ('обеспечивать', 'точный'): 1,
#  ('точный', 'и'): 1,
#  ('и', 'неуклонный'): 1,
#  ('неуклонный', 'проведение'): 1,
#  ('проведение', 'в'): 2,
#  ('жизнь', 'требование'): 1,
#  ('требование', 'законодательство'): 1,
#  ('законодательство', 'как'): 1,
#  ('известно', 'закон'): 1,
#  ('закон', 'важный'): 1,
#  ('важный', 'не'): 1,
#  ('не', 'то'): 1,
#  ('что', 'они'): 2,
#  ('они', 'записывать'): 1,
#  ('записывать', 'на'): 1,
#  ('на', 'бумага'): 1,
#  ('бумага', 'а'): 1,
#  ('а', 'то'): 1,
#  ('то', 'как'): 4,
#  ('как', 'они'): 4,
#  ('они', 'реализоваться'): 1,
#  ('реализоваться', 'и'): 1,
#  ('и', 'кто'): 1,
#  ('кто', 'они'): 2,
#  ('они', 'провожать'): 1,
#  ('провожать', 'при'): 1,
#  ('при', 'весь'): 3,
#  ('весь', 'важность'): 1,
#  ('важность', 'роль'): 1,
#  ('правотворчество', 'профессиональный'): 1,
#  ('профессиональный', 'содержание'): 1,
#  ('содержание', 'их'): 1,
#  ('их', 'работа'): 3,
#  ('работа', 'в'): 11,
#  ('в', 'правоприменительный'): 1,
#  ('правоприменительный', 'практика'): 1,
#  ('практика', 'проявляться'): 1,
#  ('проявляться', 'наиболее'): 1,
#  ('наиболее', 'полно'): 1,
#  ('полно', 'хотя'): 1,
#  ('хотя', 'бы'): 1,
#  ('бы', 'потому'): 1,
#  ('потому', 'что'): 1,
#  ('сфера', 'занятый'): 1,
#  ('занятый', 'основной'): 1,
#  ('основной', 'масса'): 1,
#  ('масса', 'юрист'): 1,
#  ('юрист', 'между'): 1,
#  ('между', 'то'): 2,
#  ('то', 'переходный'): 1,
#  ('переходный', 'период'): 1,
#  ('период', 'в'): 1,
#  ('в', 'развитие'): 8,
#  ('развитие', 'российский'): 2,
#  ('общество', 'весьма'): 1,
#  ('весьма', 'отрицательно'): 1,
#  ('отрицательно', 'сказываться'): 1,
#  ('сказываться', 'на'): 2,
#  ('на', 'работа'): 4,
#  ('работа', 'орган'): 1,
#  ('орган', 'внутренний'): 15,
#  ('внутренний', 'дело'): 15,
#  ('дело', 'прокуратура'): 1,
#  ('прокуратура', 'суд'): 1,
#  ('суд', 'другой'): 1,
#  ('другой', 'юридический'): 4,
#  ('юридический', 'учреждение'): 1,
#  ('учреждение', 'получать'): 1,
#  ('получать', 'распространение'): 2,
#  ('распространение', 'проявление'): 1,
#  ('проявление', 'предвзятость'): 1,
#  ('предвзятость', 'тенденциозный'): 1,
#  ('тенденциозный', 'подход'): 1,
#  ('подход', 'при'): 1,
#  ('при', 'проведение'): 1,
#  ('проведение', 'дознание'): 1,
#  ('дознание', 'предварительный'): 1,
#  ('предварительный', 'следствие'): 4,
#  ('следствие', 'и'): 5,
#  ('и', 'судебный'): 3,
#  ('судебный', 'разбирательство'): 5,
#  ('разбирательство', 'нередкий'): 1,
#  ('нередкий', 'случай'): 1,
#  ('случай', 'волокита'): 1,
#  ('волокита', 'черствость'): 1,
#  ('черствость', 'безразличие'): 1,
#  ('безразличие', 'к'): 1,
#  ('к', 'человеческий'): 1,
#  ('человеческий', 'судьба'): 1,
#  ('судьба', 'страница'): 1,
#  ('страница', 'современный'): 1,
#  ('современный', 'газета'): 1,
#  ('газета', 'и'): 1,
#  ('и', 'журнал'): 1,
#  ('журнал', 'изобиловать'): 1,
#  ('изобиловать', 'пример'): 1,
#  ('пример', 'не'): 1,
#  ('не', 'просто'): 1,
#  ('просто', 'противоправный'): 1,
#  ('противоправный', 'а'): 1,
#  ('а', 'циничный'): 1,
#  ('циничный', 'преступный'): 1,
#  ('преступный', 'поведение'): 2,
#  ('поведение', 'сотрудник'): 1,
#  ('сотрудник', 'различный'): 1,
#  ('различный', 'правоохранительный'): 2,
#  ('правоохранительный', 'орган'): 16,
#  ('орган', 'оборотень'): 1,
#  ('оборотень', 'в'): 1,
#  ('в', 'погон'): 1,
#  ('погон', 'вот'): 1,
#  ('вот', 'почему'): 1,
#  ('почему', 'один'): 1,
#  ('один', 'из'): 16,
#  ('из', 'основной'): 1,
#  ('основной', 'пока'): 1,
#  ('пока', 'еще'): 2,
#  ('еще', 'далеко'): 1,
#  ('не', 'решать'): 1,
#  ('решать', 'задача'): 2,
#  ('задача', 'правовой'): 1,
#  ('реформа', 'заключаться'): 1,
#  ('заключаться', 'именно'): 1,
#  ('именно', 'в'): 1,
#  ('чтобы', 'обеспечивать'): 3,
#  ('обеспечивать', 'законность'): 1,
#  ('законность', 'в'): 1,
#  ('в', 'деятельность'): 1,
#  ('деятельность', 'сам'): 1,
#  ('сам', 'юрист'): 2,
#  ('юрист', 'полностью'): 1,
#  ('полностью', 'исключать'): 1,
#  ('исключать', 'необоснованность'): 1,
#  ('необоснованность', 'задержание'): 1,
#  ('задержание', 'и'): 2,
#  ('и', 'арест'): 1,
#  ('арест', 'привлечение'): 1,
#  ('привлечение', 'гражданин'): 1,
#  ('гражданин', 'к'): 2,
#  ('к', 'ответственность'): 1,
#  ('ответственность', 'следующий'): 1,
#  ('следующий', 'важный'): 1,
#  ('важный', 'направление'): 1,
#  ('направление', 'профессионально-юридический'): 1,
#  ('профессионально-юридический', 'деятельность'): 1,
#  ('деятельность', 'являться'): 1,
#  ('являться', 'профилактика'): 1,
#  ('правонарушение', 'сегодня'): 1,
#  ('сегодня', 'становиться'): 1,
#  ('становиться', 'очевидный'): 1,
#  ('очевидный', 'что'): 1,
#  ('что', 'без'): 1,
#  ('без', 'профилактический'): 1,
#  ('профилактический', 'работа'): 1,
#  ('работа', 'общество'): 1,
#  ('общество', 'грозить'): 1,
#  ('грозить', 'девятый'): 1,
#  ('девятый', 'вал'): 1,
#  ('вал', 'преступность'): 1,
#  ('преступность', 'способный'): 1,
#  ('способный', 'погружать'): 1,
#  ('погружать', 'он'): 1,
#  ('он', 'в'): 8,
#  ('в', 'пучина'): 1,
#  ('пучина', 'криминальный'): 1,
#  ('криминальный', 'беспредел'): 1,
#  ('беспредел', 'этот'): 1,
#  ('процесс', 'усугубляться'): 1,
#  ('усугубляться', 'экономический'): 1,
#  ('экономический', 'трудность'): 1,
#  ('трудность', 'социальный'): 1,
#  ('социальный', 'напряженность'): 1,
#  ('напряженность', 'сказываться'): 1,
#  ('сказываться', 'затягиваться'): 1,
#  ('затягиваться', 'на'): 1,
#  ('на', 'долгий'): 1,
#  ('долгий', 'год'): 1,
#  ('год', 'перестройка'): 1,
#  ('перестройка', 'в'): 1,
#  ('в', 'работа'): 2,
#  ('работа', 'правоохранительный'): 2,
#  ('орган', 'ослабление'): 1,
#  ('ослабление', 'ее'): 1,
#  ('ее', 'профилактический'): 1,
#  ('профилактический', 'направленность'): 1,
#  ('направленность', 'непоследовательность'): 1,
#  ('непоследовательность', 'и'): 1,
#  ('и', 'противоречивость'): 1,
#  ('противоречивость', 'ряд'): 1,
#  ('ряд', 'принимать'): 1,
#  ('последний', 'время'): 2,
#  ('время', 'акт'): 1,
#  ('акт', 'не'): 1,
#  ('не', 'определять'): 1,
#  ('определять', 'механизм'): 1,
#  ('механизм', 'их'): 1,
#  ('их', 'реализация'): 1,
#  ('реализация', 'самостоятельный'): 1,
#  ('самостоятельный', 'направление'): 1,
#  ('направление', 'профессиональный'): 1,
#  ('профессиональный', 'юридический'): 5,
#  ('юридический', 'деятельность'): 16,
#  ('деятельность', 'представлять'): 1,
#  ('представлять', 'себя'): 8,
#  ('себя', 'и'): 2,
#  ('воспитание', 'население'): 1,
#  ('население', 'профессиональный'): 1,
#  ('профессиональный', 'деятельность'): 19,
#  ('деятельность', 'юрист'): 16,
#  ('юрист', 'исходить'): 1,
#  ('исходить', 'из'): 1,
#  ('из', 'ее'): 1,
#  ('ее', 'сущность'): 1,
#  ('сущность', 'иметь'): 1,
#  ('иметь', 'огромный'): 1,
#  ('огромный', 'воспитательный'): 1,
#  ('воспитательный', 'значение'): 2,
#  ('значение', 'в'): 2,
#  ('в', 'современный'): 2,
#  ('современный', 'условие'): 1,
#  ('условие', 'правовой'): 1,
#  ('правовой', 'культура'): 3,
#  ('культура', 'необходимый'): 1,
#  ('необходимый', 'предпосылка'): 1,
#  ('предпосылка', 'формирование'): 1,
#  ('формирование', 'правовой'): 1,
#  ('государство', 'осуществление'): 1,
#  ('осуществление', 'правовой'): 1,
#  ('реформа', 'следовать'): 1,
#  ('следовать', 'сказать'): 2,
#  ('сказать', 'что'): 1,
#  ('советский', 'время'): 5,
#  ('время', 'немало'): 1,
#  ('немало', 'делаться'): 1,
#  ('делаться', 'для'): 1,
#  ('для', 'правовой'): 1,
#  ('правовой', 'информирование'): 1,
#  ('информирование', 'гражданин'): 1,
#  ('гражданин', 'повышение'): 1,
#  ('их', 'правовой'): 1,
#  ('культура', 'ставиться'): 1,
#  ('ставиться', 'даже'): 1,
#  ('даже', 'задача'): 1,
#  ('задача', 'организация'): 1,
#  ('организация', 'правовой'): 1,
#  ('правовой', 'обучение'): 1,
#  ('обучение', 'население'): 1,
#  ('население', 'к'): 1,
#  ('сожаление', 'в'): 2,
#  ('в', 'последовать'): 1,
#  ('последовать', 'за'): 1,
#  ('за', 'то'): 2,
#  ('то', 'время'): 1,
#  ('время', 'многий'): 1,
#  ('многий', 'наработка'): 1,
#  ('наработка', 'в'): 1,
#  ('этот', 'область'): 1,
#  ('область', 'быть'): 1,
#  ('быть', 'утрачивать'): 1,
#  ('утрачивать', 'сегодня'): 1,
#  ('сегодня', 'участие'): 1,
#  ('в', 'правовой'): 2,
#  ('правовой', 'пропаганда'): 1,
#  ('пропаганда', 'и'): 2,
#  ('воспитание', 'практически'): 1,
#  ...}

# %%
adjs_nouns = []
occur_freqs = []

for bigram, value in zip(countered_bigrams.keys(), countered_bigrams.values()):
    if bigram in adj_noun_bigrams:
        adjs_nouns.append(bigram)
        occur_freqs.append(value)

d = {'ПРИЛ.-СУЩ.':adjs_nouns, 'Частота встречаемости':occur_freqs}
print('РАНЖИРОВАНИЕ ПО МЕРЕ ЧАСТОТНОСТИ')
df = pd.DataFrame(data=d, index=None)
df = df.sort_values(by=['Частота встречаемости'], ascending=False) # по убыванию, поэтому ascending=False
df
# Out:
# РАНЖИРОВАНИЕ ПО МЕРЕ ЧАСТОТНОСТИ
#                           ПРИЛ.-СУЩ.  Частота встречаемости
# 4            (российский, федерация)                     72
# 35                (внутренний, дело)                     15
# 1           (юридический, профессия)                     14
# 55         (местный, самоуправление)                     10
# 26   (действующий, законодательство)                      9
# 42          (служебный, обязанность)                      8
# 87              (учебный, заведение)                      6
# 38       (судебный, разбирательство)                      5
# 77       (квалификационный, экзамен)                      5
# 2          (правовой, регулирование)                      5
# 100            (страховой, покрытие)                      4
# 37      (предварительный, следствие)                      4
# 16                (нормативный, акт)                      4
# 20            (необходимый, условие)                      3
# 12               (активный, участие)                      3
# 110                (смертный, казнь)                      3
# 10                (физический, лицо)                      3
# 103             (соборный, уложение)                      3
# 40           (преступный, поведение)                      2
# 118      (петропавловский, крепость)                      2
# 82               (заработный, плата)                      2
# 113                (сибирский, край)                      2
# 30               (противный, случай)                      2
# 86        (договорный, документация)                      2
# 101             (корпоративный, дух)                      2
# 81        (строгий, избирательность)                      2
# 73             (умелый, организатор)                      2
# 78        (письменный, консультация)                      2
# 76               (мудрый, наставник)                      2
# 75              (интересный, статья)                      2
# ..                               ...                    ...
# 6          (политический, отношение)                      1
# 5        (законотворческий, процесс)                      1
# 36           (тенденциозный, подход)                      1
# 41         (криминальный, беспредел)                      1
# 69         (критический, обстановка)                      1
# 43            (отрицательный, образ)                      1
# 67        (достаточный, численность)                      1
# 66              (реальный, гарантия)                      1
# 65          (возможный, конфискация)                      1
# 64           (достоверный, сведение)                      1
# 63       (периодический, аттестация)                      1
# 62          (установленный, порядок)                      1
# 61     (оперативный, уполномоченная)                      1
# 60                (пожарный, надзор)                      1
# 59             (законный, основание)                      1
# 58         (специальный, литература)                      1
# 57        (следственный, управление)                      1
# 56                (известный, набор)                      1
# 54                  (отдельный, вид)                      1
# 53      (промышленный, производство)                      1
# 52           (технологический, план)                      1
# 51     (дополнительный, особенность)                      1
# 50               (подробный, анализ)                      1
# 49       (организованный, структура)                      1
# 48                (неверный, приказ)                      1
# 47                   (разный, масть)                      1
# 46      (фактический, беззащитность)                      1
# 45         (эффективный, выполнение)                      1
# 44          (всемерный, активизация)                      1
# 135             (отличный, аттестат)                      1
#
# [136 rows x 2 columns]

# %% [markdown]
# ### Мера взаимной информации
#
# Взаимная информация — статистическая функция двух случайных величин, описывающая количество информации, содержащееся в одной случайной величине относительно другой.
# Для текстов эта мера количественно рассматривает случаи взаимного появления слов.

# %%
N = len(words)
print('Размер корпуса N = ' + str(N) + ' слов.')


words_for_MI_analysis = []
for bigram in adjs_nouns:
    words_for_MI_analysis.append(bigram[0])
    words_for_MI_analysis.append(bigram[1])

words_freqs = collections.Counter(words)

words_MI, freqs_MI = [], []
for word, value in zip(words_freqs.keys(), words_freqs.values()):
    if word in words_for_MI_analysis:
        words_MI.append(word)
        freqs_MI.append(value)


# Для получения знаменателя формулы взаимной информации достаточно перемножить частоты каждого из элементов этого спсика
# (потому что слова в этом списке и так идут в правильном порядке ПРИЛ. - СУЩ.)
print(dict(zip(words_MI, freqs_MI)))
# Out:
# Размер корпуса N = 20695 слов.
# {'социальный': 29, 'направленность': 7, 'юридический': 184, 'профессия': 44, 'группа': 13, 'профессиональный': 118, 'правовой': 99, 'регулирование': 7, 'основной': 21, 'направление': 8, 'российский': 109, 'федерация': 73, 'законотворческий': 1, 'процесс': 21, 'политический': 14, 'отношение': 44, 'противоречивый': 3, 'характер': 27, 'господствующий': 1, 'класс': 1, 'действующий': 15, 'законодательство': 37, 'неопределенный': 1, 'время': 57, 'физический': 20, 'лицо': 83, 'обозримый': 1, 'перспектива': 1, 'активный': 5, 'участие': 16, 'разнообразный': 2, 'форма': 17, 'первоначальный': 2, 'рабочий': 5, 'последний': 13, 'момент': 5, 'нормативный': 13, 'акт': 17, 'заметный': 4, 'увеличение': 1, 'полный': 11, 'смысл': 9, 'существенный': 8, 'влияние': 6, 'необходимый': 31, 'условие': 31, 'целый': 3, 'ряд': 14, 'технический': 1, 'прогресс': 1, 'негативный': 3, 'урок': 1, 'соответствующий': 21, 'вывод': 3, 'значительный': 6, 'затрата': 2, 'первостепенный': 1, 'значение': 9, 'финансовый': 5, 'ресурс': 1, 'скорый': 1, 'преодоление': 2, 'противный': 2, 'случай': 25, 'простой': 3, 'сотрясание': 1, 'большой': 22, 'часть': 6, 'неуклонный': 1, 'проведение': 5, 'переходный': 1, 'период': 9, 'внутренний': 20, 'дело': 76, 'тенденциозный': 2, 'подход': 4, 'предварительный': 4, 'следствие': 6, 'судебный': 44, 'разбирательство': 5, 'человеческий': 6, 'судьба': 4, 'преступный': 2, 'поведение': 29, 'криминальный': 1, 'беспредел': 1, 'служебный': 16, 'обязанность': 39, 'отрицательный': 3, 'образ': 16, 'всемерный': 1, 'активизация': 1, 'эффективный': 1, 'выполнение': 12, 'фактический': 2, 'беззащитность': 1, 'разный': 16, 'масть': 1, 'неверный': 1, 'приказ': 2, 'организованный': 2, 'структура': 19, 'подробный': 3, 'анализ': 6, 'дополнительный': 5, 'особенность': 11, 'технологический': 1, 'план': 5, 'промышленный': 1, 'производство': 6, 'отдельный': 9, 'вид': 24, 'местный': 12, 'самоуправление': 10, 'известный': 13, 'набор': 1, 'следственный': 7, 'управление': 7, 'специальный': 11, 'литература': 5, 'законный': 12, 'основание': 3, 'пожарный': 1, 'надзор': 14, 'оперативный': 4, 'уполномоченная': 1, 'установленный': 9, 'порядок': 15, 'периодический': 1, 'аттестация': 2, 'достоверный': 2, 'сведение': 12, 'возможный': 5, 'конфискация': 1, 'реальный': 5, 'гарантия': 6, 'достаточный': 3, 'численность': 1, 'продуктивный': 1, 'мышление': 9, 'критический': 2, 'обстановка': 4, 'посторонний': 1, 'помощь': 12, 'выдающийся': 6, 'поэт': 2, 'личный': 17, 'досмотр': 4, 'умелый': 2, 'организатор': 3, 'педагогический': 5, 'поприще': 2, 'интересный': 6, 'статья': 21, 'мудрый': 2, 'наставник': 2, 'квалификационный': 12, 'экзамен': 7, 'письменный': 5, 'консультация': 4, 'краеугольный': 2, 'камень': 2, 'взаимный': 2, 'доверие': 8, 'строгий': 6, 'избирательность': 2, 'заработный': 2, 'плата': 3, 'автономный': 4, 'округ': 4, 'договорной': 2, 'дисциплина': 7, 'денежный': 2, 'сумма': 7, 'договорный': 2, 'документация': 2, 'учебный': 6, 'заведение': 6, 'индивидуальный': 5, 'планирование': 1, 'незамедлительный': 1, 'реагирование': 1, 'международный': 4, 'сотрудничество': 4, 'пожизненный': 1, 'запрет': 3, 'психический': 7, 'усилие': 3, 'прагматический': 1, 'настрой': 1, 'идейный': 1, 'убежденность': 1, 'элитный': 1, 'слой': 1, 'уставной': 1, 'капитал': 1, 'равный': 3, 'доступ': 2, 'ненадлежащий': 1, 'преимущество': 2, 'страховой': 4, 'покрытие': 4, 'корпоративный': 2, 'дух': 3, 'естественно-научный': 1, 'факультет': 5, 'соборный': 3, 'уложение': 5, 'тогдашний': 2, 'дьяк': 1, 'длинный': 1, 'название': 1, 'знаменитый': 1, 'правоискусник': 1, 'приятный': 1, 'времяпрепровождение': 1, 'екатерининский': 1, 'наказ': 4, 'понятный': 1, 'народ': 7, 'смертный': 3, 'казнь': 3, 'консервативный': 1, 'окружение': 1, 'верный': 2, 'самодержавие': 5, 'сибирский': 2, 'край': 2, 'увесистый': 1, 'том': 6, 'редакционный': 1, 'обработка': 1, 'андреевский': 1, 'звезда': 1, 'ярый': 1, 'сторонник': 2, 'петропавловский': 2, 'крепость': 4, 'горький': 1, 'ирония': 1, 'нижний': 1, 'новгород': 1, 'царствующий': 1, ...

# %%
import numpy as np
# Считаем знаменатель взаимной информации
def calculate_MI_denominators():
    """Беру каждый нечётный элемент (= частоту первого слова словосочетания), кладу в первый список.
    Беру каждый чётный элемент списка (= частоту второго слова словосочетания), кладу во второй список.
    А потом элементы этих списков попарно перемножаю. 
    Получаю на выходе знаменатель для выражения взаимной информации для каждого слова."""
    
    denominators = []
    freqs_for_the_first_words = []
    freqs_for_the_second_words = []
    for i in range(0, len(freqs_MI)):
        if i % 2 == 0:
            freqs_for_the_first_words.append(freqs_MI[i])
        else:
            freqs_for_the_second_words.append(freqs_MI[i])
    for freq_pair in list(zip(freqs_for_the_first_words, freqs_for_the_second_words)):
        denominators.append(freq_pair[0] * freq_pair[1])
    return denominators


def calculate_MI(joint_occurrence, absolute_occurrence, N=N):    
    return np.log2((joint_occurrence / absolute_occurrence) * N)

MIs = list(map(calculate_MI, occur_freqs, calculate_MI_denominators()))


d = {'Прил. + Сущ.':adjs_nouns, 'Взаимная информация':np.array(MIs)}
print('РАНЖИРОВАНИЕ ПО МЕРЕ ВЗАИМНОЙ ИНФОРМАЦИИ')
df = pd.DataFrame(data=d, index=None)
df = df.sort_values(by=['Взаимная информация'], ascending=False) # по убыванию, поэтому ascending=False
df
# Out:
# РАНЖИРОВАНИЕ ПО МЕРЕ ВЗАИМНОЙ ИНФОРМАЦИИ
#                         Прил. + Сущ.  Взаимная информация
# 42          (служебный, обязанность)            17.336995
# 35                (внутренний, дело)            15.073960
# 87              (учебный, заведение)            14.921957
# 77       (квалификационный, экзамен)            14.658923
# 95           (идейный, убежденность)            14.336995
# 119                (горький, ирония)            14.336995
# 94         (прагматический, настрой)            14.336995
# 116            (андреевский, звезда)            14.336995
# 24          (соответствующий, вывод)            14.336995
# 115        (редакционный, обработка)            14.336995
# 111      (консервативный, окружение)            14.336995
# 96                   (элитный, слой)            14.336995
# 107  (приятный, времяпрепровождение)            14.336995
# 30               (противный, случай)            14.336995
# 106      (знаменитый, правоискусник)            14.336995
# 105              (длинный, название)            14.336995
# 97               (уставной, капитал)            14.336995
# 120               (нижний, новгород)            14.336995
# 135             (отличный, аттестат)            14.336995
# 9            (неопределенный, время)            14.336995
# 128        (бессильный, негодование)            14.336995
# 134                (золотой, медаль)            14.336995
# 130            (поздний, объяснение)            14.336995
# 129        (грубый, надругательство)            14.336995
# 90   (международный, сотрудничество)            14.336995
# 122            (имущественный, ценз)            14.336995
# 127                 (тяжкий, минута)            14.336995
# 126               (тительный, сцена)            14.336995
# 13            (разнообразный, форма)            14.336995
# 125      (кассационный, департамент)            14.336995
# ..                               ...                  ...
# 50               (подробный, анализ)             9.089067
# 78        (письменный, консультация)             8.944677
# 23                (негативный, урок)             8.944677
# 44          (всемерный, активизация)             8.752032
# 58         (специальный, литература)             8.722285
# 31             (простой, сотрясание)             8.693138
# 52           (технологический, план)             8.555635
# 59             (законный, основание)             8.555635
# 11          (обозримый, перспектива)             8.504105
# 41         (криминальный, беспредел)             8.479014
# 76               (мудрый, наставник)             8.359715
# 17            (заметный, увеличение)             8.314627
# 14         (первоначальный, рабочий)             8.015067
# 8            (господствующий, класс)             7.997145
# 56                (известный, набор)             7.430104
# 33          (неуклонный, проведение)             7.292601
# 63       (периодический, аттестация)             7.260179
# 10                (физический, лицо)             6.805613
# 0       (социальный, направленность)             6.671659
# 39            (человеческий, судьба)             6.555635
# 18                   (полный, смысл)             6.549092
# 2          (правовой, регулирование)             6.075840
# 3            (основной, направление)             5.900283
# 12               (активный, участие)             5.224990
# 1           (юридический, профессия)             5.161356
# 7         (противоречивый, характер)             5.070208
# 43            (отрицательный, образ)             5.051592
# 22           (технический, прогресс)             4.428602
# 36           (тенденциозный, подход)             3.767139
# 5        (законотворческий, процесс)             1.378986
#
# [136 rows x 2 columns]

# %% [markdown]
# ### Что является термином среди словосочетаний с наибольшей частотой встречаемости в тексте

# %% [markdown]
# ![caption](freqs_terms.png)

# %% [markdown]
# ### Что является термином среди словосочетаний с наибольшим показателем взаимной информации

# %% [markdown]
# ![caption](MI_terms_.png)

# %% [markdown]
# ### Выводы

# %% [markdown]
# - Мера взаимной информации показывает, сколько количественно информации в одной величине относительно другой.
# - Терминов больше при ранжировании по частоте
