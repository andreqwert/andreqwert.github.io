# %% [markdown]
# # Домашнее задание №1
#
# Асланов А.Б., ИУ9-21М

# %% [markdown]
# - На главной странице Википедии выбрать раздел "Знаете ли Вы?" для недели, когда у меня день рождения;
# - Взять три факта и найти предложения, содержащие эти факты в статьях Википедии;
# - Сделать выводы, легко ли их было найти автоматически (легко - это когда все слова запроса в одном предложении и когда большое количество совпадающих слов).

# %% [markdown]
# Статья на факт: **["В медленном движении медленно читают"](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D0%B4%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE%D0%B5_%D1%87%D1%82%D0%B5%D0%BD%D0%B8%D0%B5)**.
#
# Автоматически найти предложения, содержащие факт, было **просто**: в статье по ссылке есть целый подраздел под названием ***Медленное чтение как часть медленного движения***, в котором все слова совпадают (если брать в соответствие лемматизированные), пусть и написаны в другом порядке.
#
# Помимо этого, не составило труда найти и незаголовочное предложение со словами запроса: *Однако в последнее время наблюдается повышенный интерес к медленному чтению как направлению в рамках медленного движения*. В нём также встречаются все слова запроса.

# %% [markdown]
# ------------------------------------------------------------------------------------------------
# Статья на факт: **["Петру I доставляли из Китая посылки с золотым песком"](https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D1%80%D0%BE%D0%B1%D1%87%D0%B0%D1%82%D0%BE%D0%B5_%D0%B7%D0%BE%D0%BB%D0%BE%D1%82%D0%BE)**.
#
# В статье **нет** предложений, однозначно содержащих этот факт. Остаются косвенные предложения, подтверждающие истинность факта, например: *Коробчатое золото — золотой песок, который поставлялся в Российскую империю из Китая для чеканки червонцев.
# Коробчатое золото использовалось для чеканки червонцев в 1701 и 1704 годах*.
#
# Но эти предложения говорят лишь о доставке коробчатого золота и изготовлении червонцев из него в указанные года, но не о доставке ***посылок лично Петру I*** из Китая.
#
# Вывод: автоматически найти предложения, содержащие факт, было **сложно**.

# %% [markdown]
# ------------------------------------------------------------------------------------------------
# Статья на факт: **["Зоны отдыха экипажей дальнемагистральных авиарейсов находятся над или под пассажирским салоном"](https://ru.wikipedia.org/wiki/%D0%97%D0%BE%D0%BD%D0%B0_%D0%BE%D1%82%D0%B4%D1%8B%D1%85%D0%B0_%D1%8D%D0%BA%D0%B8%D0%BF%D0%B0%D0%B6%D0%B0)**.
#
# Найти предложение, содержащее факт, **просто**: это - *Отсеки для отдыха экипажа обычно присутствуют на дальнемагистральных лайнерах и могут располагаться над пассажирским салоном (в этом случае в них нужно подниматься по лестнице) или рядом с ним*.
#
# В этом запросе нельзя найти все слова факта, однако "проблемные" слова, которые не совпадают явно, легко заменяются синонимами. При этом одно это предложение уже всецело покрывает текст факта.
